# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time

service = Service(executable_path=ChromeDriverManager().install())
options = Options()
driver = webdriver.Chrome(service=service, options=options)

# %%
driver.get("https://www.goodreads.com/list/show/19.Best_for_Book_Clubs")

# %%
driver.find_element(By.XPATH, "//span[@class='smallText uitext']/a[2]").text
# Out:
# '2,254 people voted'

# %%
/html/body/div[2]/div[3]/div[1]/div[2]/div[3]/div[5]/table/tbody/tr[2]/td[3]/div[2]/span/a[1]

# %%
#all_votes > table > tbody > tr:nth-child(2) > td:nth-child(3) > div:nth-child(7) > span > a:nth-child(1)

# %%
import pandas as pd

# %%
colums = ['bookUrl', 'number', 'bookname', 'author', 'prices', 'describe', 'rating', 'ratingcount', 'reviews', 'fivestars', 'fourstars', 'threestars', 'twostars', 'onestar', 'pages', 'publish', 'authorUrl', 'genre', 'score', 'votes']

# %%
df = pd.DataFrame(columns=colums)

# %%
df
# Out:
# Empty DataFrame
# Columns: [bookUrl, number, bookname, author, prices, describe, rating, ratingcount, reviews, fivestars, fourstars, threestars, twostars, onestar, pages, publish, authorUrl, genre, score, votes]
# Index: []

# %%
df = pd.read_csv('csvdataunitop.csv', delimiter='$', names=colums)

# %%
df
# Out:
#                                                 bookUrl  number  \
# 0     https://www.goodreads.com/book/show/4667024-th...       1
# 1     https://www.goodreads.com/book/show/43641.Wate...       3
# 2     https://www.goodreads.com/book/show/77203.The_...       2
# 3     https://www.goodreads.com/book/show/2657.To_Ki...       5
# 4     https://www.goodreads.com/book/show/19063.The_...       4
# ...                                                 ...     ...
# 1194  https://www.goodreads.com/book/show/61439040-1984      21
# 1195  https://www.goodreads.com/book/show/2429135.Th...      20
# 1196  https://www.goodreads.com/book/show/1618.The_C...      19
# 1197  https://www.goodreads.com/book/show/4214.Life_...      18
# 1198  https://www.goodreads.com/book/show/4989.The_R...      16
#
#                                                bookname            author  \
# 0                                              The Help  Kathryn Stockett
# ...

# %%
df.to_csv('data_1.csv', index=False)
